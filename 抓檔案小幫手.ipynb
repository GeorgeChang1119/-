# %%
def choose_from():
    global win1
    win1.destroy()
    win1=Tk()
    win1.title('抓檔案小幫手')
    win1.geometry('{}x{}+{}+{}'.format(win1_width, win1_height, x, y))
    label=Label(win1)
    label1=Label(win1,text='請點選想要抓取的檔案所在之資料夾',bg='yellow',width=40,font='Helvetica 15 bold')
    btn=Button(win1,text='選擇檔案',width=15,command=load_from)
    label1.pack()
    btn.pack()
    win1.mainloop()
   
def choose_to():
    global win1
    win1.destroy()
    win1=Tk()
    win1.title('抓檔案小幫手')
    win1.geometry('{}x{}+{}+{}'.format(win1_width, win1_height, x, y))
    label=Label(win1)
    label1=Label(win1,text='請點選想要儲存檔案的資料夾',bg='yellow',width=40,font='Helvetica 15 bold')
    btn=Button(win1,text='選擇檔案',width=15,command=load_to)
    label1.pack()
    btn.pack()
    win1.mainloop()
   
def load_from():
    global win1
    global data
    global file_path
    global DATADIR
    win1.destroy()
    win1=Tk() #建立根視窗
    win1.title('抓檔案小幫手')
    win1.geometry('{}x{}+{}+{}'.format(win1_width, win1_height, x, y))
    DATADIR=filedialog.askdirectory()+'/'
    #print(DATADIR)
    choose_to()
   
def load_to():
    global win1
    global data
    global file_path
    global newdir
    win1.destroy()
    win1=Tk() #建立根視窗
    win1.title('抓檔案小幫手')
    win1.geometry('{}x{}+{}+{}'.format(win1_width, win1_height, x, y))
    newdir=filedialog.askdirectory()+'/'
    #print(DATADIR)
    enter_word()
   
def enter_word():
    global win1
    global ent1
    win1.destroy()
    win1=Tk() #建立根視窗
    win1.title('抓檔案小幫手')
    win1.geometry('{}x{}+{}+{}'.format(win1_width, win1_height, x, y))
    label=Label(win1)
    label1=Label(win1,text='請輸入想要抓取的檔名關鍵字(ex:北供)',bg='yellow',width=40,font='Helvetica 15 bold')
    ent1=Entry(win1)
    label1.pack()                
    ent1.pack()
    btn1=Button(win1,text='匯出',width=15,command=execute_new)
    btn1.pack()

def execute_new():
    import numpy as np
    import matplotlib.pyplot as plt
    import os
    import pandas as pd
    global win1
    global DATADIR
    global newdir
    global ent1
   
    for root,dirs,files in os.walk(DATADIR):
        #print(root)
        #print(dirs)
        #print(files)
        for file in files:
            if ent1.get() in file and ent1.get()!='':
                f1=root+'/'+file
                f2=newdir+file
                shutil.copyfile(f1,f2)
           
               
    win1.destroy()
    win1=Tk()
    win1.title('抓檔案小幫手')
    win1.geometry('{}x{}+{}+{}'.format(win1_width, win1_height, x, y))
    label=Label(win1)
    label1=Label(win1,text='匯檔完成',bg='yellow',width=8,font='Helvetica 15 bold')
    btn1=Button(win1,text='關閉',width=15,command=win1.destroy)
    label1.pack()
    btn1.pack()
    win1.mainloop()



#pip install pyinstaller
import pandas as pd
import numpy as np
import scipy as sp
from tkinter import *
import tkinter as tk
from tkinter import messagebox
from tkinter import filedialog
import matplotlib.pyplot as plt
import shutil
from shutil import copy
global data_columns_name
global var_name
global ent1
win1=Tk() #建立根視窗
win1.title('抓檔案小幫手')
#########
win1_width = 700
win1_height = 700

# 獲取屏幕寬度和高度
screen_width = win1.winfo_screenwidth()
screen_height = win1.winfo_screenheight()

# 計算視窗左上角座標
x = (screen_width - win1_width) // 2
y = (screen_height - win1_height) // 2

# 設置視窗位置
win1.geometry('{}x{}+{}+{}'.format(win1_width, win1_height, x, y))
#########
label=Label(win1)
label1=Label(win1,text='說明',bg='yellow',width=15,font='Helvetica 15 bold')
label1.pack()
label2=Label(win1,text='點選以下步驟說明欄的資料夾，再輸入想尋找的檔案名稱關鍵字，即可把檔案存進你指定的資料夾',width=90,font='Helvetica 10 bold')
label2.pack()  
btn1=Button(win1,text='開始',width=15,command=choose_from)

btn1.pack()

win1.mainloop() #開啟視窗
